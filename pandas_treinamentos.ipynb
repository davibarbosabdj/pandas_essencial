# %%
import pandas as pd

# %%
# leitura do df

#gas = pd.read_table('2004-2021.tsv') - Original do Kaggle
#gas.head()

gas = pd.read_csv("dados/GasPricesinBrazil_2004-2019.csv", delimiter=";")
gas.head()
# Out:
#    Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0           0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1           1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2           2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3           3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4           4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  ETANOL HIDRATADO                           127              R$/l
# 1  ETANOL HIDRATADO                           387              R$/l
# 2  ETANOL HIDRATADO                           192              R$/l
# 3  ETANOL HIDRATADO                           162              R$/l
# 4  ETANOL HIDRATADO                           103              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  PREÇO MÁXIMO REVENDA  \
# ...

# %%
# Informações gerais sobre o df
gas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 106823 entries, 0 to 106822
# Data columns (total 21 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   Unnamed: 0                     106823 non-null  int64
#  1   DATA INICIAL                   106823 non-null  object
#  2   DATA FINAL                     106823 non-null  object
#  3   REGIÃO                         106823 non-null  object
#  4   ESTADO                         106823 non-null  object
#  5   PRODUTO                        106823 non-null  object
#  6   NÚMERO DE POSTOS PESQUISADOS   106823 non-null  int64
#  7   UNIDADE DE MEDIDA              106823 non-null  object
#  8   PREÇO MÉDIO REVENDA            106823 non-null  float64
#  9   DESVIO PADRÃO REVENDA          106823 non-null  float64
#  10  PREÇO MÍNIMO REVENDA           106823 non-null  float64
#  11  PREÇO MÁXIMO REVENDA           106823 non-null  float64
# ...

# %%
gas.shape
# Out:
# (106823, 21)

# %%
# Retorna uma lista com todos os nomes das colunas
gas.columns
# Out:
# Index(['Unnamed: 0', 'DATA INICIAL', 'DATA FINAL', 'REGIÃO', 'ESTADO',
#        'PRODUTO', 'NÚMERO DE POSTOS PESQUISADOS', 'UNIDADE DE MEDIDA',
#        'PREÇO MÉDIO REVENDA', 'DESVIO PADRÃO REVENDA', 'PREÇO MÍNIMO REVENDA',
#        'PREÇO MÁXIMO REVENDA', 'MARGEM MÉDIA REVENDA',
#        'COEF DE VARIAÇÃO REVENDA', 'PREÇO MÉDIO DISTRIBUIÇÃO',
#        'DESVIO PADRÃO DISTRIBUIÇÃO', 'PREÇO MÍNIMO DISTRIBUIÇÃO',
#        'PREÇO MÁXIMO DISTRIBUIÇÃO', 'COEF DE VARIAÇÃO DISTRIBUIÇÃO', 'MÊS',
#        'ANO'],
#       dtype='object')

# %% [markdown]
# #### Renomear as colunas do dataframe
# podemos usar o ```df.rename()``` e passar um dicionario com a chave sendo o nome da coluna e o valor o novo nome
# para alterar o df original é só colocar o ```inplace = True```
#
# ```personagens.rename(columns={"nome":"Nome completo"})```
#
# Uma outra forma de renomeaar todas as colunas de um data frame é pra passar uma lista com os novos nomes das colunas para o atributo
#
# ```personagens.columns = ['NOME', 'IDADE', 'PESO', 'EH_JEDI']```

# %% [markdown]
# #### Series

# %%
gas.head()
# Out:
#    Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0           0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1           1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2           2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3           3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4           4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  ETANOL HIDRATADO                           127              R$/l
# 1  ETANOL HIDRATADO                           387              R$/l
# 2  ETANOL HIDRATADO                           192              R$/l
# 3  ETANOL HIDRATADO                           162              R$/l
# 4  ETANOL HIDRATADO                           103              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  PREÇO MÁXIMO REVENDA  \
# ...

# %%
# Selecionando uma coluna inteira
gas['ESTADO']
# Out:
# 0            DISTRITO FEDERAL
# 1                       GOIAS
# 2                 MATO GROSSO
# 3          MATO GROSSO DO SUL
# 4                     ALAGOAS
#                  ...
# 106818    RIO GRANDE DO NORTE
# 106819      RIO GRANDE DO SUL
# 106820         SANTA CATARINA
# 106821              SAO PAULO
# 106822                SERGIPE
# Name: ESTADO, Length: 106823, dtype: object

# %%
type(gas['ESTADO'])
# Out:
# pandas.core.series.Series

# %%
# selecionando a observação indexada no indice [1] do df
gas.iloc[1]
# Out:
# Unnamed: 0                                      1
# DATA INICIAL                           2004-05-09
# DATA FINAL                             2004-05-15
# REGIÃO                               CENTRO OESTE
# ESTADO                                      GOIAS
# PRODUTO                          ETANOL HIDRATADO
# NÚMERO DE POSTOS PESQUISADOS                  387
# UNIDADE DE MEDIDA                            R$/l
# PREÇO MÉDIO REVENDA                         1.162
# DESVIO PADRÃO REVENDA                       0.114
# PREÇO MÍNIMO REVENDA                         0.89
# PREÇO MÁXIMO REVENDA                        1.449
# MARGEM MÉDIA REVENDA                        0.399
# COEF DE VARIAÇÃO REVENDA                    0.098
# PREÇO MÉDIO DISTRIBUIÇÃO                    0.763
# DESVIO PADRÃO DISTRIBUIÇÃO                  0.088
# PREÇO MÍNIMO DISTRIBUIÇÃO                  0.5013
# PREÇO MÁXIMO DISTRIBUIÇÃO                    1.05
# COEF DE VARIAÇÃO DISTRIBUIÇÃO               0.115
# ...

# %% [markdown]
# #### Atribuindo dados

# %%
gas.head()
# Out:
#    Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0           0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1           1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2           2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3           3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4           4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  ETANOL HIDRATADO                           127              R$/l
# 1  ETANOL HIDRATADO                           387              R$/l
# 2  ETANOL HIDRATADO                           192              R$/l
# 3  ETANOL HIDRATADO                           162              R$/l
# 4  ETANOL HIDRATADO                           103              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  PREÇO MÁXIMO REVENDA  \
# ...

# %% [markdown]
# #### Atribuindo constantes/valores

# %%
gas['PRODUTO'] # A series retornada à coluna, NÃO É UMA COPIA, mas sim, uma REFERÊNCIA/VIEW à coluna do dataframe
# Out:
# 0         ETANOL HIDRATADO
# 1         ETANOL HIDRATADO
# 2         ETANOL HIDRATADO
# 3         ETANOL HIDRATADO
# 4         ETANOL HIDRATADO
#                 ...
# 106818                 GNV
# 106819                 GNV
# 106820                 GNV
# 106821                 GNV
# 106822                 GNV
# Name: PRODUTO, Length: 106823, dtype: object

# %%
produto_view = gas['PRODUTO']
produto_view
# Out:
# 0         ETANOL HIDRATADO
# 1         ETANOL HIDRATADO
# 2         ETANOL HIDRATADO
# 3         ETANOL HIDRATADO
# 4         ETANOL HIDRATADO
#                 ...
# 106818                 GNV
# 106819                 GNV
# 106820                 GNV
# 106821                 GNV
# 106822                 GNV
# Name: PRODUTO, Length: 106823, dtype: object

# %%
produto_copy_bkp = gas['PRODUTO'].copy() # retorna uma copia 'PRODUTO'
produto_copy_bkp
# Out:
# 0         ETANOL HIDRATADO
# 1         ETANOL HIDRATADO
# 2         ETANOL HIDRATADO
# 3         ETANOL HIDRATADO
# 4         ETANOL HIDRATADO
#                 ...
# 106818                 GNV
# 106819                 GNV
# 106820                 GNV
# 106821                 GNV
# 106822                 GNV
# Name: PRODUTO, Length: 106823, dtype: object

# %%
# 
gas['PRODUTO'] = 'Combustível'
gas.head()
# Out:
#    Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0           0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1           1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2           2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3           3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4           4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
#
#        PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  Combustível                           127              R$/l
# 1  Combustível                           387              R$/l
# 2  Combustível                           192              R$/l
# 3  Combustível                           162              R$/l
# 4  Combustível                           103              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  PREÇO MÁXIMO REVENDA  \
# ...

# %%
produto_view
# Out:
# 0         ETANOL HIDRATADO
# 1         ETANOL HIDRATADO
# 2         ETANOL HIDRATADO
# 3         ETANOL HIDRATADO
# 4         ETANOL HIDRATADO
#                 ...
# 106818                 GNV
# 106819                 GNV
# 106820                 GNV
# 106821                 GNV
# 106822                 GNV
# Name: PRODUTO, Length: 106823, dtype: object

# %%
nrows, ncols = gas.shape
nrows, ncols
# Out:
# (106823, 21)

# %%
novos_produtos = [f'Produto {i}' for i in range(nrows)]
len(novos_produtos)
# Out:
# 106823

# %%
# A quantidade de elementos da lista 'novos_produtos' é igual ao número de linhas do dataframe 
gas['PRODUTO'] = novos_produtos

# %%
gas.head()
# Out:
#    Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0           0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1           1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2           2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3           3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4           4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
#
#      PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  Produto 0                           127              R$/l
# 1  Produto 1                           387              R$/l
# 2  Produto 2                           192              R$/l
# 3  Produto 3                           162              R$/l
# 4  Produto 4                           103              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  PREÇO MÁXIMO REVENDA  \
# 0                1.288                  0.016  ...                 1.350
# ...

# %%
produto_view
print("\n")
produto_copy_bkp
# Out:
# 0         ETANOL HIDRATADO
# 1         ETANOL HIDRATADO
# 2         ETANOL HIDRATADO
# 3         ETANOL HIDRATADO
# 4         ETANOL HIDRATADO
#                 ...
# 106818                 GNV
# 106819                 GNV
# 106820                 GNV
# 106821                 GNV
# 106822                 GNV
# Name: PRODUTO, Length: 106823, dtype: object

# %%
# Voltando para os produtos originais 
gas['PRODUTO'] = produto_copy_bkp
gas.head()
# Out:
#    Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0           0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1           1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2           2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3           3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4           4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  ETANOL HIDRATADO                           127              R$/l
# 1  ETANOL HIDRATADO                           387              R$/l
# 2  ETANOL HIDRATADO                           192              R$/l
# 3  ETANOL HIDRATADO                           162              R$/l
# 4  ETANOL HIDRATADO                           103              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  PREÇO MÁXIMO REVENDA  \
# ...

# %% [markdown]
# #### COLUNAS

# %% [markdown]
# Para criar uma nova coluna em um data frame, basta atribuirmos uma_lista/series de valores pu uma constante a uma **nova chave** do data frame.
#
# PS. A Quantidade de valores da lista precisa ser igual ao número de linhas/registros do data frame.

# %%
# Criando uma coluna a partir de um valor constante/default
# todas as linhas terão o mesmo valor para esta nova coluna 
gas['coluna sem noção'] = "DEFAULT"
gas
# Out:
#         Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO  \
# 0                0   2004-05-09  2004-05-15  CENTRO OESTE
# 1                1   2004-05-09  2004-05-15  CENTRO OESTE
# 2                2   2004-05-09  2004-05-15  CENTRO OESTE
# 3                3   2004-05-09  2004-05-15  CENTRO OESTE
# 4                4   2004-05-09  2004-05-15      NORDESTE
# ...            ...          ...         ...           ...
# 106818      106818   2019-06-23  2019-06-29      NORDESTE
# 106819      106819   2019-06-23  2019-06-29           SUL
# 106820      106820   2019-06-23  2019-06-29           SUL
# 106821      106821   2019-06-23  2019-06-29       SUDESTE
# 106822      106822   2019-06-23  2019-06-29      NORDESTE
#
#                      ESTADO           PRODUTO  NÚMERO DE POSTOS PESQUISADOS  \
# 0          DISTRITO FEDERAL  ETANOL HIDRATADO                           127
# 1                     GOIAS  ETANOL HIDRATADO                           387
# ...

# %%
gas['coluna a partir de lista'] = range(gas.shape[0])
gas
# Out:
#         Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO  \
# 0                0   2004-05-09  2004-05-15  CENTRO OESTE
# 1                1   2004-05-09  2004-05-15  CENTRO OESTE
# 2                2   2004-05-09  2004-05-15  CENTRO OESTE
# 3                3   2004-05-09  2004-05-15  CENTRO OESTE
# 4                4   2004-05-09  2004-05-15      NORDESTE
# ...            ...          ...         ...           ...
# 106818      106818   2019-06-23  2019-06-29      NORDESTE
# 106819      106819   2019-06-23  2019-06-29           SUL
# 106820      106820   2019-06-23  2019-06-29           SUL
# 106821      106821   2019-06-23  2019-06-29       SUDESTE
# 106822      106822   2019-06-23  2019-06-29      NORDESTE
#
#                      ESTADO           PRODUTO  NÚMERO DE POSTOS PESQUISADOS  \
# 0          DISTRITO FEDERAL  ETANOL HIDRATADO                           127
# 1                     GOIAS  ETANOL HIDRATADO                           387
# ...

# %%
# Lembre: A QUANTIDADE DE ELEMENTOS TEM QUE SER DO TAMANHO DO DF 
#gas['não funciona'] = [1,2,3]

# %%
gas['PREÇO MÉDIO REVENDA (dólares)'] = gas['PREÇO MÉDIO REVENDA'] * 6.0
gas
# Out:
#         Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO  \
# 0                0   2004-05-09  2004-05-15  CENTRO OESTE
# 1                1   2004-05-09  2004-05-15  CENTRO OESTE
# 2                2   2004-05-09  2004-05-15  CENTRO OESTE
# 3                3   2004-05-09  2004-05-15  CENTRO OESTE
# 4                4   2004-05-09  2004-05-15      NORDESTE
# ...            ...          ...         ...           ...
# 106818      106818   2019-06-23  2019-06-29      NORDESTE
# 106819      106819   2019-06-23  2019-06-29           SUL
# 106820      106820   2019-06-23  2019-06-29           SUL
# 106821      106821   2019-06-23  2019-06-29       SUDESTE
# 106822      106822   2019-06-23  2019-06-29      NORDESTE
#
#                      ESTADO           PRODUTO  NÚMERO DE POSTOS PESQUISADOS  \
# 0          DISTRITO FEDERAL  ETANOL HIDRATADO                           127
# 1                     GOIAS  ETANOL HIDRATADO                           387
# ...

# %% [markdown]
# PS. Obviamente, a lógica correta em converter o preço dos combustiveis em reais para dólares não é considerar uma txa de câmbio fixa, uma vez que cada preço em real foi aferido em um momento diferente.

# %% [markdown]
# #### ÍNDICES - ACESSO A ELEMENTOS DO DF

# %%
gas.index
# Out:
# RangeIndex(start=0, stop=106823, step=1)

# %% [markdown]
# Use ```list(data.index)``` ou ```data.index.to_list()``` para converter um Rangeindex para uma python list.
#
# #### Exemplo de Data Frame com índices textuais (labels)

# %%
pesquisa_de_satisfação = pd.DataFrame({
    "bom": [50, 21, 100],
    'ruim': [131, 2, 30],
    'pessimo': [30, 20, 1]
}, index=["XboxOne", 'Playstation4', 'Switch'])

# %%
pesquisa_de_satisfação.head()
# Out:
#               bom  ruim  pessimo
# XboxOne        50   131       30
# Playstation4   21     2       20
# Switch        100    30        1

# %%
pesquisa_de_satisfação.index
# Out:
# Index(['XboxOne', 'Playstation4', 'Switch'], dtype='object')

# %% [markdown]
# #### Selecionando uma ou mais amostras (indexação)
#
# Index-based selection (seleção baseada em índices)
#
# Mostrando linhas especificass de um Data Frame:
#
# ```iloc```: seleciona elementos do dataframe, baseado em seu **índice(número)** --> row-first, column-second

# %%
# Selecionando uma amostra/linha 
gas.iloc[1]
# Out:
# Unnamed: 0                                      1
# DATA INICIAL                           2004-05-09
# DATA FINAL                             2004-05-15
# REGIÃO                               CENTRO OESTE
# ESTADO                                      GOIAS
# PRODUTO                          ETANOL HIDRATADO
# NÚMERO DE POSTOS PESQUISADOS                  387
# UNIDADE DE MEDIDA                            R$/l
# PREÇO MÉDIO REVENDA                         1.162
# DESVIO PADRÃO REVENDA                       0.114
# PREÇO MÍNIMO REVENDA                         0.89
# PREÇO MÁXIMO REVENDA                        1.449
# MARGEM MÉDIA REVENDA                        0.399
# COEF DE VARIAÇÃO REVENDA                    0.098
# PREÇO MÉDIO DISTRIBUIÇÃO                    0.763
# DESVIO PADRÃO DISTRIBUIÇÃO                  0.088
# PREÇO MÍNIMO DISTRIBUIÇÃO                  0.5013
# PREÇO MÁXIMO DISTRIBUIÇÃO                    1.05
# COEF DE VARIAÇÃO DISTRIBUIÇÃO               0.115
# ...

# %%
# Selecionando multiplas observações 
gas.iloc[:6]
# Out:
#    Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0           0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1           1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2           2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3           3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4           4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
# 5           5   2004-05-09  2004-05-15      NORDESTE               BAHIA
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  ETANOL HIDRATADO                           127              R$/l
# 1  ETANOL HIDRATADO                           387              R$/l
# 2  ETANOL HIDRATADO                           192              R$/l
# 3  ETANOL HIDRATADO                           162              R$/l
# 4  ETANOL HIDRATADO                           103              R$/l
# ...

# %%
# Selecionando as linhas de indice de 10 a 15 (incluso)
gas.iloc[10:16]
# Out:
#     Unnamed: 0 DATA INICIAL  DATA FINAL    REGIÃO               ESTADO  \
# 10          10   2004-05-09  2004-05-15  NORDESTE                PIAUI
# 11          11   2004-05-09  2004-05-15  NORDESTE  RIO GRANDE DO NORTE
# 12          12   2004-05-09  2004-05-15  NORDESTE              SERGIPE
# 13          13   2004-05-09  2004-05-15     NORTE                 ACRE
# 14          14   2004-05-09  2004-05-15     NORTE                AMAPA
# 15          15   2004-05-09  2004-05-15     NORTE             AMAZONAS
#
#              PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 10  ETANOL HIDRATADO                            89              R$/l
# 11  ETANOL HIDRATADO                           131              R$/l
# 12  ETANOL HIDRATADO                            57              R$/l
# 13  ETANOL HIDRATADO                            33              R$/l
# 14  ETANOL HIDRATADO                            15              R$/l
# ...

# %%
# selecionando as linhas de indice 1, 5, 10, 15
gas.iloc[[1, 5, 10, 15]]
# Out:
#     Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO    ESTADO  \
# 1            1   2004-05-09  2004-05-15  CENTRO OESTE     GOIAS
# 5            5   2004-05-09  2004-05-15      NORDESTE     BAHIA
# 10          10   2004-05-09  2004-05-15      NORDESTE     PIAUI
# 15          15   2004-05-09  2004-05-15         NORTE  AMAZONAS
#
#              PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 1   ETANOL HIDRATADO                           387              R$/l
# 5   ETANOL HIDRATADO                           408              R$/l
# 10  ETANOL HIDRATADO                            89              R$/l
# 15  ETANOL HIDRATADO                            53              R$/l
#
#     PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  PREÇO MÉDIO DISTRIBUIÇÃO  \
# 1                 1.162                  0.114  ...                     0.763
# 5                 1.383                  0.132  ...                     0.957
# ...

# %%
# Selecionando as linhas observações de indices 5, 1, 15, 10
gas.iloc[[5, 1, 15, 10]]
# Out:
#     Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO    ESTADO  \
# 5            5   2004-05-09  2004-05-15      NORDESTE     BAHIA
# 1            1   2004-05-09  2004-05-15  CENTRO OESTE     GOIAS
# 15          15   2004-05-09  2004-05-15         NORTE  AMAZONAS
# 10          10   2004-05-09  2004-05-15      NORDESTE     PIAUI
#
#              PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 5   ETANOL HIDRATADO                           408              R$/l
# 1   ETANOL HIDRATADO                           387              R$/l
# 15  ETANOL HIDRATADO                            53              R$/l
# 10  ETANOL HIDRATADO                            89              R$/l
#
#     PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  PREÇO MÉDIO DISTRIBUIÇÃO  \
# 5                 1.383                  0.132  ...                     0.957
# 1                 1.162                  0.114  ...                     0.763
# ...

# %%
# Retornar o valor da linha de indice 1, coluna 4 ['ESTADO']
gas.iloc[1,4]
# Out:
# 'GOIAS'

# %% [markdown]
# #### Label-based selection (seleção baseadas em Rótulos)
#
# ```loc```: seleciona elementos do Dataframe, baseado em seus rótulos --> row-first, column-second
#
# Este método é primariamente baseado nas labels da colunas, porém podemos utilizar com um array booleano também.
#
# Uma informação importante sobre loc é: quando nenhum item é encontrado ele retorna um KeyError.
#
# Funcionamento do método:
#
# O método funciona desta maneira: ```df.loc[<linhas>, <colunas>]```

# %%
pesquisa_de_satisfação
# Out:
#               bom  ruim  pessimo
# XboxOne        50   131       30
# Playstation4   21     2       20
# Switch        100    30        1

# %%
# retorna a linha de indice 0 (implicito) == usando o iloc
pesquisa_de_satisfação.iloc[0]
# Out:
# bom         50
# ruim       131
# pessimo     30
# Name: XboxOne, dtype: int64

# %%
# Retorna a linha cujo o rotulo do indice é XboxOne
pesquisa_de_satisfação.loc['XboxOne']
# Out:
# bom         50
# ruim       131
# pessimo     30
# Name: XboxOne, dtype: int64

# %%
# Acessar uma determinada especificação 
pesquisa_de_satisfação.loc["Playstation4", "ruim"]
# Out:
# 2

# %%
pesquisa_de_satisfação.loc[['XboxOne', 'Switch']]
# Out:
#          bom  ruim  pessimo
# XboxOne   50   131       30
# Switch   100    30        1

# %%
# Retorne todas as linhas e apenas as colunas com rotulos 'bom' e 'pessimo'

#pesquisa_de_satisfação[["bom", 'pessimo']]

pesquisa_de_satisfação.loc[:,['bom', 'pessimo']]
# Out:
#               bom  pessimo
# XboxOne        50       30
# Playstation4   21       20
# Switch        100        1

# %%
# Lembrar da regra da loc[linha, coluna]
gas.loc[[1,2], ['PRODUTO', "PREÇO MÉDIO REVENDA"]]
# Out:
#             PRODUTO  PREÇO MÉDIO REVENDA
# 1  ETANOL HIDRATADO                1.162
# 2  ETANOL HIDRATADO                1.389

# %%
# Podemos combinar operadores lógicos para chegar ao resultado que queremos
gas.loc[(gas["PREÇO MÉDIO REVENDA"]) > 2]
# Out:
#         Unnamed: 0 DATA INICIAL  DATA FINAL    REGIÃO               ESTADO  \
# 770            770   2004-11-21  2004-11-27     NORTE                AMAPA
# 772            772   2004-11-21  2004-11-27     NORTE                 PARA
# 774            774   2004-11-21  2004-11-27     NORTE              RORAIMA
# 797            797   2004-11-28  2004-12-04     NORTE                AMAPA
# 799            799   2004-11-28  2004-12-04     NORTE                 PARA
# ...            ...          ...         ...       ...                  ...
# 106818      106818   2019-06-23  2019-06-29  NORDESTE  RIO GRANDE DO NORTE
# 106819      106819   2019-06-23  2019-06-29       SUL    RIO GRANDE DO SUL
# 106820      106820   2019-06-23  2019-06-29       SUL       SANTA CATARINA
# 106821      106821   2019-06-23  2019-06-29   SUDESTE            SAO PAULO
# 106822      106822   2019-06-23  2019-06-29  NORDESTE              SERGIPE
#
# ...

# %% [markdown]
# #### Selecionando um ou mais atributos(colunas)

# %%
gas.head()
# Out:
#    Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0           0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1           1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2           2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3           3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4           4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  ETANOL HIDRATADO                           127              R$/l
# 1  ETANOL HIDRATADO                           387              R$/l
# 2  ETANOL HIDRATADO                           192              R$/l
# 3  ETANOL HIDRATADO                           162              R$/l
# 4  ETANOL HIDRATADO                           103              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  PREÇO MÉDIO DISTRIBUIÇÃO  \
# ...

# %%
# Retornando a coluna/atributo "ESTADO"
gas['ESTADO']
# Out:
# 0            DISTRITO FEDERAL
# 1                       GOIAS
# 2                 MATO GROSSO
# 3          MATO GROSSO DO SUL
# 4                     ALAGOAS
#                  ...
# 106818    RIO GRANDE DO NORTE
# 106819      RIO GRANDE DO SUL
# 106820         SANTA CATARINA
# 106821              SAO PAULO
# 106822                SERGIPE
# Name: ESTADO, Length: 106823, dtype: object

# %%
gas.loc[:, 'ESTADO'].unique()
# Out:
# array(['DISTRITO FEDERAL', 'GOIAS', 'MATO GROSSO', 'MATO GROSSO DO SUL',
#        'ALAGOAS', 'BAHIA', 'CEARA', 'MARANHAO', 'PARAIBA', 'PERNAMBUCO',
#        'PIAUI', 'RIO GRANDE DO NORTE', 'SERGIPE', 'ACRE', 'AMAPA',
#        'AMAZONAS', 'PARA', 'RONDONIA', 'RORAIMA', 'TOCANTINS',
#        'ESPIRITO SANTO', 'MINAS GERAIS', 'RIO DE JANEIRO', 'SAO PAULO',
#        'PARANA', 'RIO GRANDE DO SUL', 'SANTA CATARINA'], dtype=object)

# %% [markdown]
# #### Removendo Atributos (colunas) do Data Frame

# %%
# Deleta/Remove no propio df (inplace)
del gas["Unnamed: 0"]

# %%
gas.head()
# Out:
#   DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  ETANOL HIDRATADO                           127              R$/l
# 1  ETANOL HIDRATADO                           387              R$/l
# 2  ETANOL HIDRATADO                           192              R$/l
# 3  ETANOL HIDRATADO                           162              R$/l
# 4  ETANOL HIDRATADO                           103              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  ...  \
# 0                1.288                  0.016                  1.19  ...
# ...

# %% [markdown]
# #### Salvando um Data Frame
#
# Para salvarmos um Data Frame para um arquivo csv basta usarmos o método ```to_csv```. Por padrão, esse método salva os índices da tabela como uma coluna no csv.
# Como no geral tais índices são números de o a n-1. Não há necessidade para isso (veja que removemos anteriormente a coluna que tinha isto).
# Desta forma, utilize o parâmetro: ```index=False.```.
#
# Por padrão, o método utilizará a "," como separador de colunas. Caso queira alterá-lo, utilize o parâmetro ```sep```.

# %%
gas.to_csv("C:/Users/joaod/OneDrive/Documentos/Projetos/pandas_essencial/Gaspreprocessado.csv", index = False)

# %% [markdown]
# #### Seleção Condicional: Filtrando amostras
#
# Durante nossas análises exploratórias, frequentemente filtraremos nossas amostras, a partir de certas **condições**, para fins de anáslise mais especifica. Existem algumas maneiras de fazermos tal filtragem. Antes disso, vamos carregar nosso pré-processado que salvamos no item anterior.

# %%
datagas = pd.read_csv('C:/Users/joaod/OneDrive/Documentos/Projetos/pandas_essencial/Gaspreprocessado.csv')

# %%
datagas.head()
# Out:
#   DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  ETANOL HIDRATADO                           127              R$/l
# 1  ETANOL HIDRATADO                           387              R$/l
# 2  ETANOL HIDRATADO                           192              R$/l
# 3  ETANOL HIDRATADO                           162              R$/l
# 4  ETANOL HIDRATADO                           103              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  ...  \
# 0                1.288                  0.016                  1.19  ...
# ...

# %%
del datagas['coluna sem noção']
del datagas['coluna a partir de lista']
del datagas['PREÇO MÉDIO REVENDA (dólares)']

# %%
datagas.head()
# Out:
#   DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  ETANOL HIDRATADO                           127              R$/l
# 1  ETANOL HIDRATADO                           387              R$/l
# 2  ETANOL HIDRATADO                           192              R$/l
# 3  ETANOL HIDRATADO                           162              R$/l
# 4  ETANOL HIDRATADO                           103              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  \
# 0                1.288                  0.016                  1.19
# ...

# %%
# Mostra todos os estados cujos os preços dos combustíveis foram aferidos
# Valores unicos presentes para o atributo estado
datagas['ESTADO'].unique()
# Out:
# array(['DISTRITO FEDERAL', 'GOIAS', 'MATO GROSSO', 'MATO GROSSO DO SUL',
#        'ALAGOAS', 'BAHIA', 'CEARA', 'MARANHAO', 'PARAIBA', 'PERNAMBUCO',
#        'PIAUI', 'RIO GRANDE DO NORTE', 'SERGIPE', 'ACRE', 'AMAPA',
#        'AMAZONAS', 'PARA', 'RONDONIA', 'RORAIMA', 'TOCANTINS',
#        'ESPIRITO SANTO', 'MINAS GERAIS', 'RIO DE JANEIRO', 'SAO PAULO',
#        'PARANA', 'RIO GRANDE DO SUL', 'SANTA CATARINA'], dtype=object)

# %%
# series de booleans em uma var
selecaoSP = datagas['ESTADO'] == 'SAO PAULO'
selecaoSP
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 106818    False
# 106819    False
# 106820    False
# 106821     True
# 106822    False
# Name: ESTADO, Length: 106823, dtype: bool

# %%
selecaoCE = datagas['ESTADO'] == 'CEARA'
selecaoCE
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 106818    False
# 106819    False
# 106820    False
# 106821    False
# 106822    False
# Name: ESTADO, Length: 106823, dtype: bool

# %%
datagas[selecaoSP]
# Out:
#        DATA INICIAL  DATA FINAL   REGIÃO     ESTADO           PRODUTO  \
# 23       2004-05-09  2004-05-15  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 50       2004-05-16  2004-05-22  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 77       2004-05-23  2004-05-29  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 104      2004-05-30  2004-06-05  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 131      2004-06-06  2004-06-12  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# ...             ...         ...      ...        ...               ...
# 106724   2019-06-23  2019-06-29  SUDESTE  SAO PAULO       ÓLEO DIESEL
# 106751   2019-06-23  2019-06-29  SUDESTE  SAO PAULO   ÓLEO DIESEL S10
# 106778   2019-06-23  2019-06-29  SUDESTE  SAO PAULO    GASOLINA COMUM
# 106805   2019-06-23  2019-06-29  SUDESTE  SAO PAULO               GLP
# 106821   2019-06-23  2019-06-29  SUDESTE  SAO PAULO               GNV
#
#         NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# ...

# %%
datagas[selecaoCE]
# Out:
#        DATA INICIAL  DATA FINAL    REGIÃO ESTADO           PRODUTO  \
# 6        2004-05-09  2004-05-15  NORDESTE  CEARA  ETANOL HIDRATADO
# 33       2004-05-16  2004-05-22  NORDESTE  CEARA  ETANOL HIDRATADO
# 60       2004-05-23  2004-05-29  NORDESTE  CEARA  ETANOL HIDRATADO
# 87       2004-05-30  2004-06-05  NORDESTE  CEARA  ETANOL HIDRATADO
# 114      2004-06-06  2004-06-12  NORDESTE  CEARA  ETANOL HIDRATADO
# ...             ...         ...       ...    ...               ...
# 106705   2019-06-23  2019-06-29  NORDESTE  CEARA       ÓLEO DIESEL
# 106732   2019-06-23  2019-06-29  NORDESTE  CEARA   ÓLEO DIESEL S10
# 106759   2019-06-23  2019-06-29  NORDESTE  CEARA    GASOLINA COMUM
# 106786   2019-06-23  2019-06-29  NORDESTE  CEARA               GLP
# 106810   2019-06-23  2019-06-29  NORDESTE  CEARA               GNV
#
#         NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# 6                                278              R$/l                1.453
# ...

# %%
#Selecionar os dados do estado Ceará
postosCE = datagas.query('ESTADO == "CEARA"')
postosCE
# Out:
#        DATA INICIAL  DATA FINAL    REGIÃO ESTADO           PRODUTO  \
# 6        2004-05-09  2004-05-15  NORDESTE  CEARA  ETANOL HIDRATADO
# 33       2004-05-16  2004-05-22  NORDESTE  CEARA  ETANOL HIDRATADO
# 60       2004-05-23  2004-05-29  NORDESTE  CEARA  ETANOL HIDRATADO
# 87       2004-05-30  2004-06-05  NORDESTE  CEARA  ETANOL HIDRATADO
# 114      2004-06-06  2004-06-12  NORDESTE  CEARA  ETANOL HIDRATADO
# ...             ...         ...       ...    ...               ...
# 106705   2019-06-23  2019-06-29  NORDESTE  CEARA       ÓLEO DIESEL
# 106732   2019-06-23  2019-06-29  NORDESTE  CEARA   ÓLEO DIESEL S10
# 106759   2019-06-23  2019-06-29  NORDESTE  CEARA    GASOLINA COMUM
# 106786   2019-06-23  2019-06-29  NORDESTE  CEARA               GLP
# 106810   2019-06-23  2019-06-29  NORDESTE  CEARA               GNV
#
#         NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# 6                                278              R$/l                1.453
# ...

# %%
# Resetando os indices do df - drop = True é para os antigos indices não virarem coluna
postosCE.reset_index(drop=True, inplace=True)
postosCE
# Out:
#      DATA INICIAL  DATA FINAL    REGIÃO ESTADO           PRODUTO  \
# 0      2004-05-09  2004-05-15  NORDESTE  CEARA  ETANOL HIDRATADO
# 1      2004-05-16  2004-05-22  NORDESTE  CEARA  ETANOL HIDRATADO
# 2      2004-05-23  2004-05-29  NORDESTE  CEARA  ETANOL HIDRATADO
# 3      2004-05-30  2004-06-05  NORDESTE  CEARA  ETANOL HIDRATADO
# 4      2004-06-06  2004-06-12  NORDESTE  CEARA  ETANOL HIDRATADO
# ...           ...         ...       ...    ...               ...
# 4258   2019-06-23  2019-06-29  NORDESTE  CEARA       ÓLEO DIESEL
# 4259   2019-06-23  2019-06-29  NORDESTE  CEARA   ÓLEO DIESEL S10
# 4260   2019-06-23  2019-06-29  NORDESTE  CEARA    GASOLINA COMUM
# 4261   2019-06-23  2019-06-29  NORDESTE  CEARA               GLP
# 4262   2019-06-23  2019-06-29  NORDESTE  CEARA               GNV
#
#       NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# 0                              278              R$/l                1.453
# ...

# %%
#tambem pode ser feito assim 
postosCE = datagas.query('ESTADO == "CEARA"').reset_index(drop=True)
postosCE
# Out:
#      DATA INICIAL  DATA FINAL    REGIÃO ESTADO           PRODUTO  \
# 0      2004-05-09  2004-05-15  NORDESTE  CEARA  ETANOL HIDRATADO
# 1      2004-05-16  2004-05-22  NORDESTE  CEARA  ETANOL HIDRATADO
# 2      2004-05-23  2004-05-29  NORDESTE  CEARA  ETANOL HIDRATADO
# 3      2004-05-30  2004-06-05  NORDESTE  CEARA  ETANOL HIDRATADO
# 4      2004-06-06  2004-06-12  NORDESTE  CEARA  ETANOL HIDRATADO
# ...           ...         ...       ...    ...               ...
# 4258   2019-06-23  2019-06-29  NORDESTE  CEARA       ÓLEO DIESEL
# 4259   2019-06-23  2019-06-29  NORDESTE  CEARA   ÓLEO DIESEL S10
# 4260   2019-06-23  2019-06-29  NORDESTE  CEARA    GASOLINA COMUM
# 4261   2019-06-23  2019-06-29  NORDESTE  CEARA               GLP
# 4262   2019-06-23  2019-06-29  NORDESTE  CEARA               GNV
#
#       NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# 0                              278              R$/l                1.453
# ...

# %%
p2 = postosCE['PREÇO MÉDIO REVENDA'] > 2.0

# %%
postosCE[p2]
# Out:
#      DATA INICIAL  DATA FINAL    REGIÃO ESTADO           PRODUTO  \
# 99     2006-04-16  2006-04-22  NORDESTE  CEARA  ETANOL HIDRATADO
# 100    2006-04-23  2006-04-29  NORDESTE  CEARA  ETANOL HIDRATADO
# 101    2006-04-30  2006-05-06  NORDESTE  CEARA  ETANOL HIDRATADO
# 102    2006-05-07  2006-05-13  NORDESTE  CEARA  ETANOL HIDRATADO
# 103    2006-05-14  2006-05-20  NORDESTE  CEARA  ETANOL HIDRATADO
# ...           ...         ...       ...    ...               ...
# 4258   2019-06-23  2019-06-29  NORDESTE  CEARA       ÓLEO DIESEL
# 4259   2019-06-23  2019-06-29  NORDESTE  CEARA   ÓLEO DIESEL S10
# 4260   2019-06-23  2019-06-29  NORDESTE  CEARA    GASOLINA COMUM
# 4261   2019-06-23  2019-06-29  NORDESTE  CEARA               GLP
# 4262   2019-06-23  2019-06-29  NORDESTE  CEARA               GNV
#
#       NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# 99                             264              R$/l                2.019
# ...

# %% [markdown]
# #### Selecionando regitros de postos de São Paulo ou Ceará com gasolina comum

# %%
datagas.head()
# Out:
#   DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  ETANOL HIDRATADO                           127              R$/l
# 1  ETANOL HIDRATADO                           387              R$/l
# 2  ETANOL HIDRATADO                           192              R$/l
# 3  ETANOL HIDRATADO                           162              R$/l
# 4  ETANOL HIDRATADO                           103              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  \
# 0                1.288                  0.016                  1.19
# ...

# %%
#selecionando os dados dos estados de SP e CE
selecaoCESP = (datagas['ESTADO'] == 'SAO PAULO') | (datagas['ESTADO'] == 'CEARA')

# %%
datagas[selecaoCESP]
# Out:
#        DATA INICIAL  DATA FINAL    REGIÃO     ESTADO           PRODUTO  \
# 6        2004-05-09  2004-05-15  NORDESTE      CEARA  ETANOL HIDRATADO
# 23       2004-05-09  2004-05-15   SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 33       2004-05-16  2004-05-22  NORDESTE      CEARA  ETANOL HIDRATADO
# 50       2004-05-16  2004-05-22   SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 60       2004-05-23  2004-05-29  NORDESTE      CEARA  ETANOL HIDRATADO
# ...             ...         ...       ...        ...               ...
# 106778   2019-06-23  2019-06-29   SUDESTE  SAO PAULO    GASOLINA COMUM
# 106786   2019-06-23  2019-06-29  NORDESTE      CEARA               GLP
# 106805   2019-06-23  2019-06-29   SUDESTE  SAO PAULO               GLP
# 106810   2019-06-23  2019-06-29  NORDESTE      CEARA               GNV
# 106821   2019-06-23  2019-06-29   SUDESTE  SAO PAULO               GNV
#
#         NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# ...

# %%
#selecionando o produto como gasolina comum
selecaoCESP2 = datagas['PRODUTO'] == 'GASOLINA COMUM'

# %%
datagas[selecaoCESP2]
# Out:
#        DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 12064    2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 12065    2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 12066    2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 12067    2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 12068    2004-05-09  2004-05-15      NORDESTE             ALAGOAS
# ...             ...         ...           ...                 ...
# 106776   2019-06-23  2019-06-29         NORTE             RORAIMA
# 106777   2019-06-23  2019-06-29           SUL      SANTA CATARINA
# 106778   2019-06-23  2019-06-29       SUDESTE           SAO PAULO
# 106779   2019-06-23  2019-06-29      NORDESTE             SERGIPE
# 106780   2019-06-23  2019-06-29         NORTE           TOCANTINS
#
#                PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 12064   GASOLINA COMUM                           128              R$/l
# ...

# %%
#selecionando os precos de revenda > 2
selecaoCESP3 = (datagas['PREÇO MÉDIO REVENDA'] >2)

# %%
# Juntando todas as seleções para formar um df só, com as observações dos estados
# de SP e CE, com GASOLINA COMUM e PREÇO MÉDIO REVENDA > 2

selecaofinal = selecaoCESP & selecaoCESP2 & selecaoCESP3

# %%
#Atribuindo as seleções a uma variável
CESP = datagas[selecaofinal]

# %%
CESP.head()
# Out:
#       DATA INICIAL  DATA FINAL    REGIÃO ESTADO         PRODUTO  \
# 12070   2004-05-09  2004-05-15  NORDESTE  CEARA  GASOLINA COMUM
# 12097   2004-05-16  2004-05-22  NORDESTE  CEARA  GASOLINA COMUM
# 12124   2004-05-23  2004-05-29  NORDESTE  CEARA  GASOLINA COMUM
# 12151   2004-05-30  2004-06-05  NORDESTE  CEARA  GASOLINA COMUM
# 12178   2004-06-06  2004-06-12  NORDESTE  CEARA  GASOLINA COMUM
#
#        NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# 12070                           321              R$/l                2.148
# 12097                           321              R$/l                2.147
# 12124                           329              R$/l                2.147
# 12151                           317              R$/l                2.148
# 12178                           326              R$/l                2.147
#
#        DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  PREÇO MÁXIMO REVENDA  \
# ...

# %%
CESP['ESTADO'].unique()
# Out:
# array(['CEARA', 'SAO PAULO'], dtype=object)

# %% [markdown]
# #### Selecionando registros dos anos de 2008, 2010 e 2012

# %%
#Alternativa1
anos1 = (datagas['ANO'] == 2008) | (datagas['ANO'] == 2010) | (datagas['ANO'] == 2012)

# %%
#Alternativa2
lista_anos = [2008, 2010, 2012]

s = datagas['ANO'].isin(lista_anos)
datagas[s]
# Out:
#       DATA INICIAL  DATA FINAL        REGIÃO               ESTADO  \
# 5098    2008-01-06  2008-01-12  CENTRO OESTE     DISTRITO FEDERAL
# 5099    2008-01-06  2008-01-12  CENTRO OESTE                GOIAS
# 5100    2008-01-06  2008-01-12  CENTRO OESTE          MATO GROSSO
# 5101    2008-01-06  2008-01-12  CENTRO OESTE   MATO GROSSO DO SUL
# 5102    2008-01-06  2008-01-12      NORDESTE              ALAGOAS
# ...            ...         ...           ...                  ...
# 55754   2012-12-30  2013-01-05      NORDESTE  RIO GRANDE DO NORTE
# 55755   2012-12-30  2013-01-05           SUL    RIO GRANDE DO SUL
# 55756   2012-12-30  2013-01-05           SUL       SANTA CATARINA
# 55757   2012-12-30  2013-01-05       SUDESTE            SAO PAULO
# 55758   2012-12-30  2013-01-05      NORDESTE              SERGIPE
#
#                 PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 5098   ETANOL HIDRATADO                            80              R$/l
# ...

# %%
#Alternativa3
datagas.query('ANO in @lista_anos')
# Out:
#       DATA INICIAL  DATA FINAL        REGIÃO               ESTADO  \
# 5098    2008-01-06  2008-01-12  CENTRO OESTE     DISTRITO FEDERAL
# 5099    2008-01-06  2008-01-12  CENTRO OESTE                GOIAS
# 5100    2008-01-06  2008-01-12  CENTRO OESTE          MATO GROSSO
# 5101    2008-01-06  2008-01-12  CENTRO OESTE   MATO GROSSO DO SUL
# 5102    2008-01-06  2008-01-12      NORDESTE              ALAGOAS
# ...            ...         ...           ...                  ...
# 55754   2012-12-30  2013-01-05      NORDESTE  RIO GRANDE DO NORTE
# 55755   2012-12-30  2013-01-05           SUL    RIO GRANDE DO SUL
# 55756   2012-12-30  2013-01-05           SUL       SANTA CATARINA
# 55757   2012-12-30  2013-01-05       SUDESTE            SAO PAULO
# 55758   2012-12-30  2013-01-05      NORDESTE              SERGIPE
#
#                 PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 5098   ETANOL HIDRATADO                            80              R$/l
# ...

# %% [markdown]
# #### Iterando com Dataframes

# %%
for index, row in datagas.head(10).iterrows():
    print(f'\n indice {index} ==> {row["ESTADO"]}')
# Out:
#  indice 0 ==> DISTRITO FEDERAL
#
#  indice 1 ==> GOIAS
#
#  indice 2 ==> MATO GROSSO
#
#  indice 3 ==> MATO GROSSO DO SUL
#
#  indice 4 ==> ALAGOAS
#
#  indice 5 ==> BAHIA
#
#  indice 6 ==> CEARA
#
#  indice 7 ==> MARANHAO
#
#  indice 8 ==> PARAIBA
#
#  indice 9 ==> PERNAMBUCO

# %%
for index, row in datagas.head(10).iterrows():
    print(f'\n indice {index} ==> {row}')
# Out:
#  indice 0 ==> DATA INICIAL                           2004-05-09
# DATA FINAL                             2004-05-15
# REGIÃO                               CENTRO OESTE
# ESTADO                           DISTRITO FEDERAL
# PRODUTO                          ETANOL HIDRATADO
# NÚMERO DE POSTOS PESQUISADOS                  127
# UNIDADE DE MEDIDA                            R$/l
# PREÇO MÉDIO REVENDA                         1.288
# DESVIO PADRÃO REVENDA                       0.016
# PREÇO MÍNIMO REVENDA                         1.19
# PREÇO MÁXIMO REVENDA                         1.35
# MARGEM MÉDIA REVENDA                        0.463
# COEF DE VARIAÇÃO REVENDA                    0.012
# PREÇO MÉDIO DISTRIBUIÇÃO                    0.825
# DESVIO PADRÃO DISTRIBUIÇÃO                   0.11
# PREÇO MÍNIMO DISTRIBUIÇÃO                  0.4201
# PREÇO MÁXIMO DISTRIBUIÇÃO                  0.9666
# COEF DE VARIAÇÃO DISTRIBUIÇÃO               0.133
# ...

# %% [markdown]
# #### Preparação de Dados

# %%
datagas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 106823 entries, 0 to 106822
# Data columns (total 20 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   DATA INICIAL                   106823 non-null  object
#  1   DATA FINAL                     106823 non-null  object
#  2   REGIÃO                         106823 non-null  object
#  3   ESTADO                         106823 non-null  object
#  4   PRODUTO                        106823 non-null  object
#  5   NÚMERO DE POSTOS PESQUISADOS   106823 non-null  int64
#  6   UNIDADE DE MEDIDA              106823 non-null  object
#  7   PREÇO MÉDIO REVENDA            106823 non-null  float64
#  8   DESVIO PADRÃO REVENDA          106823 non-null  float64
#  9   PREÇO MÍNIMO REVENDA           106823 non-null  float64
#  10  PREÇO MÁXIMO REVENDA           106823 non-null  float64
#  11  MARGEM MÉDIA REVENDA           106823 non-null  object
# ...

# %%
data_pre = datagas.copy()

# %%
# Conversão de datas

data_pre['DATA INICIAL'] = pd.to_datetime(data_pre['DATA INICIAL'])
data_pre['DATA FINAL'] = pd.to_datetime(data_pre['DATA FINAL'])

data_pre.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 106823 entries, 0 to 106822
# Data columns (total 20 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   DATA INICIAL                   106823 non-null  datetime64[ns]
#  1   DATA FINAL                     106823 non-null  datetime64[ns]
#  2   REGIÃO                         106823 non-null  object
#  3   ESTADO                         106823 non-null  object
#  4   PRODUTO                        106823 non-null  object
#  5   NÚMERO DE POSTOS PESQUISADOS   106823 non-null  int64
#  6   UNIDADE DE MEDIDA              106823 non-null  object
#  7   PREÇO MÉDIO REVENDA            106823 non-null  float64
#  8   DESVIO PADRÃO REVENDA          106823 non-null  float64
#  9   PREÇO MÍNIMO REVENDA           106823 non-null  float64
#  10  PREÇO MÁXIMO REVENDA           106823 non-null  float64
# ...

# %%
#Convertendo atributos para numerico

listanum = ['MARGEM MÉDIA REVENDA', 'PREÇO MÉDIO DISTRIBUIÇÃO', 'DESVIO PADRÃO DISTRIBUIÇÃO', 'PREÇO MÍNIMO DISTRIBUIÇÃO', 'PREÇO MÁXIMO DISTRIBUIÇÃO', 'COEF DE VARIAÇÃO DISTRIBUIÇÃO' ]

for atributo in listanum: 
    #converte a coluna para um tipo numerico, em caso de erro na conversão, um valor vazio NaN será atribuido no lugar
    data_pre[atributo] = pd.to_numeric(data_pre[atributo], errors = 'coerce')
    
data_pre.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 106823 entries, 0 to 106822
# Data columns (total 20 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   DATA INICIAL                   106823 non-null  datetime64[ns]
#  1   DATA FINAL                     106823 non-null  datetime64[ns]
#  2   REGIÃO                         106823 non-null  object
#  3   ESTADO                         106823 non-null  object
#  4   PRODUTO                        106823 non-null  object
#  5   NÚMERO DE POSTOS PESQUISADOS   106823 non-null  int64
#  6   UNIDADE DE MEDIDA              106823 non-null  object
#  7   PREÇO MÉDIO REVENDA            106823 non-null  float64
#  8   DESVIO PADRÃO REVENDA          106823 non-null  float64
#  9   PREÇO MÍNIMO REVENDA           106823 non-null  float64
#  10  PREÇO MÁXIMO REVENDA           106823 non-null  float64
# ...

# %% [markdown]
# #### Limpeza de dados

# %%
n = data_pre['PREÇO MÉDIO DISTRIBUIÇÃO'].isnull()

data_pre[n].head(3)
# Out:
#      DATA INICIAL DATA FINAL REGIÃO   ESTADO           PRODUTO  \
# 1903   2005-09-25 2005-10-01  NORTE     PARA  ETANOL HIDRATADO
# 1958   2005-10-09 2005-10-15  NORTE  RORAIMA  ETANOL HIDRATADO
# 2012   2005-10-23 2005-10-29  NORTE  RORAIMA  ETANOL HIDRATADO
#
#       NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# 1903                             2              R$/l                1.694
# 1958                             3              R$/l                2.000
# 2012                             3              R$/l                2.277
#
#       DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  PREÇO MÁXIMO REVENDA  \
# 1903                  0.283                  1.69                  2.09
# 1958                  0.000                  2.00                  2.00
# 2012                  0.023                  2.25                  2.29
#
#       MARGEM MÉDIA REVENDA  COEF DE VARIAÇÃO REVENDA  \
# 1903                   NaN                     0.167
# ...

# %%
#Nos dados originais, quais eram os valores do PREÇO MEDIO DE DISTRIBUICAO dos registros originais

datagas[n].head()
# Out:
#      DATA INICIAL  DATA FINAL REGIÃO   ESTADO           PRODUTO  \
# 1903   2005-09-25  2005-10-01  NORTE     PARA  ETANOL HIDRATADO
# 1958   2005-10-09  2005-10-15  NORTE  RORAIMA  ETANOL HIDRATADO
# 2012   2005-10-23  2005-10-29  NORTE  RORAIMA  ETANOL HIDRATADO
# 2497   2006-02-26  2006-03-04  NORTE  RORAIMA  ETANOL HIDRATADO
# 3199   2006-08-27  2006-09-02  NORTE  RORAIMA  ETANOL HIDRATADO
#
#       NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# 1903                             2              R$/l                1.694
# 1958                             3              R$/l                2.000
# 2012                             3              R$/l                2.277
# 2497                            11              R$/l                2.182
# 3199                            22              R$/l                2.285
#
#       DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  PREÇO MÁXIMO REVENDA  \
# ...

# %%
#Retorna uma copia do dataframe datapre com todos os valores NaN de todas as colunas agora preenchidas com 0.
#Para alterar o propio df, use o argumento inplace=True

data_pre_fill = data_pre.fillna(0)
data_pre_fill.head()
# Out:
#   DATA INICIAL DATA FINAL        REGIÃO              ESTADO           PRODUTO  \
# 0   2004-05-09 2004-05-15  CENTRO OESTE    DISTRITO FEDERAL  ETANOL HIDRATADO
# 1   2004-05-09 2004-05-15  CENTRO OESTE               GOIAS  ETANOL HIDRATADO
# 2   2004-05-09 2004-05-15  CENTRO OESTE         MATO GROSSO  ETANOL HIDRATADO
# 3   2004-05-09 2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL  ETANOL HIDRATADO
# 4   2004-05-09 2004-05-15      NORDESTE             ALAGOAS  ETANOL HIDRATADO
#
#    NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# 0                           127              R$/l                1.288
# 1                           387              R$/l                1.162
# 2                           192              R$/l                1.389
# 3                           162              R$/l                1.262
# 4                           103              R$/l                1.181
#
# ...

# %%
data_pre_fill[n]
# Out:
#        DATA INICIAL DATA FINAL   REGIÃO          ESTADO           PRODUTO  \
# 1903     2005-09-25 2005-10-01    NORTE            PARA  ETANOL HIDRATADO
# 1958     2005-10-09 2005-10-15    NORTE         RORAIMA  ETANOL HIDRATADO
# 2012     2005-10-23 2005-10-29    NORTE         RORAIMA  ETANOL HIDRATADO
# 2497     2006-02-26 2006-03-04    NORTE         RORAIMA  ETANOL HIDRATADO
# 3199     2006-08-27 2006-09-02    NORTE         RORAIMA  ETANOL HIDRATADO
# ...             ...        ...      ...             ...               ...
# 106664   2019-06-16 2019-06-22  SUDESTE    MINAS GERAIS               GNV
# 106666   2019-06-16 2019-06-22      SUL          PARANA               GNV
# 106811   2019-06-23 2019-06-29  SUDESTE  ESPIRITO SANTO               GNV
# 106813   2019-06-23 2019-06-29  SUDESTE    MINAS GERAIS               GNV
# 106815   2019-06-23 2019-06-29      SUL          PARANA               GNV
#
#         NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# ...

# %%
data_pre_fill = data_pre.fillna(value = {
    "PREÇO MÉDIO DISTRIBUIÇÃO": 10,
    'DESVIO PADRÃO DISTRIBUIÇÃO': 20,
    'PREÇO MÁXIMO DISTRIBUIÇÃO': 30
})

# %%
data_pre_fill[n].head()
# Out:
#      DATA INICIAL DATA FINAL REGIÃO   ESTADO           PRODUTO  \
# 1903   2005-09-25 2005-10-01  NORTE     PARA  ETANOL HIDRATADO
# 1958   2005-10-09 2005-10-15  NORTE  RORAIMA  ETANOL HIDRATADO
# 2012   2005-10-23 2005-10-29  NORTE  RORAIMA  ETANOL HIDRATADO
# 2497   2006-02-26 2006-03-04  NORTE  RORAIMA  ETANOL HIDRATADO
# 3199   2006-08-27 2006-09-02  NORTE  RORAIMA  ETANOL HIDRATADO
#
#       NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# 1903                             2              R$/l                1.694
# 1958                             3              R$/l                2.000
# 2012                             3              R$/l                2.277
# 2497                            11              R$/l                2.182
# 3199                            22              R$/l                2.285
#
#       DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  PREÇO MÁXIMO REVENDA  \
# ...

# %%
#Para remover os NaNs

data_pre.dropna(inplace = True)

# %%
data_pre.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 103392 entries, 0 to 106822
# Data columns (total 20 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   DATA INICIAL                   103392 non-null  datetime64[ns]
#  1   DATA FINAL                     103392 non-null  datetime64[ns]
#  2   REGIÃO                         103392 non-null  object
#  3   ESTADO                         103392 non-null  object
#  4   PRODUTO                        103392 non-null  object
#  5   NÚMERO DE POSTOS PESQUISADOS   103392 non-null  int64
#  6   UNIDADE DE MEDIDA              103392 non-null  object
#  7   PREÇO MÉDIO REVENDA            103392 non-null  float64
#  8   DESVIO PADRÃO REVENDA          103392 non-null  float64
#  9   PREÇO MÍNIMO REVENDA           103392 non-null  float64
#  10  PREÇO MÁXIMO REVENDA           103392 non-null  float64
# ...

# %% [markdown]
# #### Estatísticas descritivas

# %%
data_pre.to_csv("C:/Users/joaod/OneDrive/Documentos/Projetos/pandas_essencial/Gaspreprocessado-final.csv", index = False)

# %%
data_final = pd.read_csv("C:/Users/joaod/OneDrive/Documentos/Projetos/pandas_essencial/Gaspreprocessado-final.csv")

# %%
#Retorna um df com as principais medidas(mean, median, max e min e etc)
data_final.describe()['PREÇO MÉDIO REVENDA']
# Out:
# count    103392.000000
# mean         10.784472
# std          17.685852
# min           0.766000
# 25%           2.073000
# 50%           2.723000
# 75%           3.745000
# max          99.357000
# Name: PREÇO MÉDIO REVENDA, dtype: float64

# %%
stats = data_final.describe()

stats[['PREÇO MÉDIO REVENDA', 'PREÇO MÁXIMO REVENDA']]
# Out:
#        PREÇO MÉDIO REVENDA  PREÇO MÁXIMO REVENDA
# count        103392.000000         103392.000000
# mean             10.784472             12.458686
# std              17.685852             20.801190
# min               0.766000              0.999000
# 25%               2.073000              2.330000
# 50%               2.723000              3.000000
# 75%               3.745000              4.150000
# max              99.357000            120.000000

# %%
data_final[['PREÇO MÉDIO REVENDA', 'PREÇO MÁXIMO REVENDA']].describe()
# Out:
#        PREÇO MÉDIO REVENDA  PREÇO MÁXIMO REVENDA
# count        103392.000000         103392.000000
# mean             10.784472             12.458686
# std              17.685852             20.801190
# min               0.766000              0.999000
# 25%               2.073000              2.330000
# 50%               2.723000              3.000000
# 75%               3.745000              4.150000
# max              99.357000            120.000000

# %%
#Selecionar apenas algumas medidas
stats.loc[['min', 'max', 'mean']]
# Out:
#       NÚMERO DE POSTOS PESQUISADOS  PREÇO MÉDIO REVENDA  \
# min                       1.000000             0.766000
# max                    4167.000000            99.357000
# mean                    240.511935            10.784472
#
#       DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  PREÇO MÁXIMO REVENDA  \
# min                0.000000              0.590000              0.999000
# max               10.748000             90.000000            120.000000
# mean               0.652589              9.334931             12.458686
#
#       MARGEM MÉDIA REVENDA  COEF DE VARIAÇÃO REVENDA  \
# min               0.001000                  0.000000
# max              36.847000                  0.262000
# mean              2.225151                  0.045749
#
#       PREÇO MÉDIO DISTRIBUIÇÃO  DESVIO PADRÃO DISTRIBUIÇÃO  \
# min                   0.506000                    0.000000
# max                  83.137000                   18.385000
# ...

# %%
#Selecionar apenas algumas medidas para estas colunas

stats.loc[['min', 'max', 'mean'], ['PREÇO MÉDIO REVENDA', 'PREÇO MÉDIO DISTRIBUIÇÃO']]
# Out:
#       PREÇO MÉDIO REVENDA  PREÇO MÉDIO DISTRIBUIÇÃO
# min              0.766000                  0.506000
# max             99.357000                 83.137000
# mean            10.784472                  8.559322

# %%
#Selecionando o min do preço minimo de revenda

stats.loc[['min'], ['PREÇO MÍNIMO REVENDA']]
# Out:
#      PREÇO MÍNIMO REVENDA
# min                  0.59

# %%
mean = data_final['PREÇO MÉDIO REVENDA'].mean()
std = data_final['PREÇO MÉDIO REVENDA'].std()

print(f'A Média dos preços minimos de revenda é {mean} +- {std}')
# Out:
# A Média dos preços minimos de revenda é 10.784472386645001 +- 17.68585159703446

# %%
sorted(data_final['ESTADO'].unique())
# Out:
# ['ACRE',
#  'ALAGOAS',
#  'AMAPA',
#  'AMAZONAS',
#  'BAHIA',
#  'CEARA',
#  'DISTRITO FEDERAL',
#  'ESPIRITO SANTO',
#  'GOIAS',
#  'MARANHAO',
#  'MATO GROSSO',
#  'MATO GROSSO DO SUL',
#  'MINAS GERAIS',
#  'PARA',
#  'PARAIBA',
#  'PARANA',
#  'PERNAMBUCO',
#  'PIAUI',
#  'RIO DE JANEIRO',
#  'RIO GRANDE DO NORTE',
#  'RIO GRANDE DO SUL',
#  'RONDONIA',
#  'RORAIMA',
#  'SANTA CATARINA',
#  'SAO PAULO',
#  'SERGIPE',
#  'TOCANTINS']

# %%
# Quantos registros (aferições) cada estado possui
# .value_counts() conta a frequencia de uma variavel (de preferencia categorica)

data_final['ESTADO'].value_counts()
# Out:
# BAHIA                  4263
# RIO DE JANEIRO         4262
# SAO PAULO              4261
# RIO GRANDE DO SUL      4249
# PARAIBA                4240
# PERNAMBUCO             4236
# SERGIPE                4202
# SANTA CATARINA         4164
# MINAS GERAIS           4142
# ESPIRITO SANTO         4079
# MATO GROSSO DO SUL     4076
# ALAGOAS                4020
# RIO GRANDE DO NORTE    3999
# CEARA                  3964
# PARANA                 3902
# AMAZONAS               3713
# MATO GROSSO            3703
# PARA                   3477
# MARANHAO               3470
# ACRE                   3463
# RORAIMA                3457
# TOCANTINS              3453
# GOIAS                  3449
# RONDONIA               3441
# PIAUI                  3394
# DISTRITO FEDERAL       3317
# AMAPA                  2996
# Name: ESTADO, dtype: int64

# %%
#Converte uma series em um data frame
data_final['ESTADO'].value_counts().to_frame()
# Out:
#                      ESTADO
# BAHIA                  4263
# RIO DE JANEIRO         4262
# SAO PAULO              4261
# RIO GRANDE DO SUL      4249
# PARAIBA                4240
# PERNAMBUCO             4236
# SERGIPE                4202
# SANTA CATARINA         4164
# MINAS GERAIS           4142
# ESPIRITO SANTO         4079
# MATO GROSSO DO SUL     4076
# ALAGOAS                4020
# RIO GRANDE DO NORTE    3999
# CEARA                  3964
# PARANA                 3902
# AMAZONAS               3713
# MATO GROSSO            3703
# PARA                   3477
# MARANHAO               3470
# ACRE                   3463
# RORAIMA                3457
# TOCANTINS              3453
# GOIAS                  3449
# RONDONIA               3441
# PIAUI                  3394
# DISTRITO FEDERAL       3317
# AMAPA                  2996

# %% [markdown]
# #### Executando funções para cada item de um Data Frame ou Series
#
# Uma alternativa ao ```for-loop``` que vimos anteriormente e que é lento, é usarmos funções própias do pandas que aplicam/mapeiam uma dada função a todos os elementos de um df ou series, retornando novos elementos 'transformados'.
#
# * ```apply()```: usado para aplicar uma função ao longo de um eixo de um df ou em valores de uma series.

# %%
def nossa_soma(series):
    return series.sum()

# %%
df = pd.DataFrame({
    'A': [1, 2, 3, 4],
    'B': [10, 20, 30, 40],
    'C': [100, 200, 300, 400]}, 
    index = ['Linha 1', 'Linha 2', 'Linha 3', 'Linha 4'])

df
# Out:
#          A   B    C
# Linha 1  1  10  100
# Linha 2  2  20  200
# Linha 3  3  30  300
# Linha 4  4  40  400

# %%
df['SOMA (A, B, C)'] = df.apply(nossa_soma, axis = 1)
df
# Out:
#          A   B    C  SOMA (A, B, C)
# Linha 1  1  10  100             111
# Linha 2  2  20  200             222
# Linha 3  3  30  300             333
# Linha 4  4  40  400             444

# %%
df.loc['Linha 5 Soma']= df.apply(nossa_soma, axis=0)
df
# Out:
#                A    B     C  SOMA (A, B, C)
# Linha 1        1   10   100             111
# Linha 2        2   20   200             222
# Linha 3        3   30   300             333
# Linha 4        4   40   400             444
# Linha 5 Soma  10  100  1000            1110

# %%
df['MÉDIA (A,B,C)'] = df[['A', 'B', 'C']].apply(lambda series: series.mean(), axis=1)
df
# Out:
#                A    B     C  SOMA (A, B, C)  MÉDIA (A,B,C)
# Linha 1        1   10   100             111           37.0
# Linha 2        2   20   200             222           74.0
# Linha 3        3   30   300             333          111.0
# Linha 4        4   40   400             444          148.0
# Linha 5 Soma  10  100  1000            1110          370.0

# %%
#Aplica a labda function abaixo para cada elemento da coluna
df['C * 2'] = df['C'].apply(lambda x: x * 2)
df
# Out:
#      A    B    C  C * 2
# 0  1.0  2.0  3.0    6.0
# 1  4.0  5.0  6.0   12.0
# 2  7.0  8.0  9.0   18.0
# 3  NaN  NaN  NaN    NaN

# %% [markdown]
# * ```applymap()```: usado para aplicar uma função para cada elemento (element-wise) de um dataframe

# %%
#Retorna um novo df com todos os elementos ao quadrado
#poderiamos usar uma função ao invés de uma lambda function
df.applymap(lambda x: x ** 2)
# Out:
#                 A      B        C  SOMA (A, B, C)  MÉDIA (A,B,C)    C * 2
# Linha 1         1    100    10000           12321         1369.0    40000
# Linha 2         4    400    40000           49284         5476.0   160000
# Linha 3         9    900    90000          110889        12321.0   360000
# Linha 4        16   1600   160000          197136        21904.0   640000
# Linha 5 Soma  100  10000  1000000         1232100       136900.0  4000000

# %% [markdown]
# * ```map()```: usado para aplicar uma função para cada elemnto (element-wise) de uma series.

# %%
nomes = pd.Series(['João', 'Maria', 'Alice', 'Pedro'])
nomes
# Out:
# 0     João
# 1    Maria
# 2    Alice
# 3    Pedro
# dtype: object

# %% [markdown]
# #### Agrupamento
#
# ```groupby```: Usado para criar grupos de elemntos (e.x.., baseado nos valores de um atributo (categórico)).
#
# Funções podem esntão ser aplicadas para os elementos de cada grupo, de modo que os resultados de cada grupo são combinados.

# %%
data_final.head(3)
# Out:
#   DATA INICIAL  DATA FINAL        REGIÃO            ESTADO           PRODUTO  \
# 0   2004-05-09  2004-05-15  CENTRO OESTE  DISTRITO FEDERAL  ETANOL HIDRATADO
# 1   2004-05-09  2004-05-15  CENTRO OESTE             GOIAS  ETANOL HIDRATADO
# 2   2004-05-09  2004-05-15  CENTRO OESTE       MATO GROSSO  ETANOL HIDRATADO
#
#    NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# 0                           127              R$/l                1.288
# 1                           387              R$/l                1.162
# 2                           192              R$/l                1.389
#
#    DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  PREÇO MÁXIMO REVENDA  \
# 0                  0.016                  1.19                 1.350
# 1                  0.114                  0.89                 1.449
# 2                  0.097                  1.18                 1.760
#
#    MARGEM MÉDIA REVENDA  COEF DE VARIAÇÃO REVENDA  PREÇO MÉDIO DISTRIBUIÇÃO  \
# ...

# %%
grupos = data_final.groupby('REGIÃO')
grupos

# %%
#Retorna o codigo obtidos pelo goupby
grupos.groups
# Out:
# {'CENTRO OESTE': [0, 1, 2, 3, 27, 28, 29, 30, 54, 55, 56, 57, 81, 82, 83, 84, 108, 109, 110, 111, 135, 136, 137, 138, 162, 163, 164, 165, 189, 190, 191, 192, 216, 217, 218, 219, 243, 244, 245, 246, 270, 271, 272, 273, 297, 298, 299, 300, 324, 325, 326, 327, 351, 352, 353, 354, 378, 379, 380, 381, 405, 406, 407, 408, 432, 433, 434, 435, 459, 460, 461, 462, 486, 487, 488, 489, 513, 514, 515, 516, 540, 541, 542, 543, 567, 568, 569, 570, 594, 595, 596, 597, 621, 622, 623, 624, 648, 649, 650, 651, ...], 'NORDESTE': [4, 5, 6, 7, 8, 9, 10, 11, 12, 31, 32, 33, 34, 35, 36, 37, 38, 39, 58, 59, 60, 61, 62, 63, 64, 65, 66, 85, 86, 87, 88, 89, 90, 91, 92, 93, 112, 113, 114, 115, 116, 117, 118, 119, 120, 139, 140, 141, 142, 143, 144, 145, 146, 147, 166, 167, 168, 169, 170, 171, 172, 173, 174, 193, 194, 195, 196, 197, 198, 199, 200, 201, 220, 221, 222, 223, 224, 225, 226, 227, 228, 247, 248, 249, 250, 251, 252, 253, 254, 255, 274, 275, 276, 277, 278, 279, 280, 281, 282, 301, ...], 'NORTE': [13, 14,
# ...

# %%
#Retorna os indices das linhas/observações de cada grupo
grupos.indices
# Out:
# {'CENTRO OESTE': array([     0,      1,      2, ..., 103363, 103364, 103383], dtype=int64),
#  'NORDESTE': array([     4,      5,      6, ..., 103385, 103387, 103391], dtype=int64),
#  'NORTE': array([    13,     14,     15, ..., 103374, 103375, 103379], dtype=int64),
#  'SUDESTE': array([    20,     21,     22, ..., 103377, 103386, 103390], dtype=int64),
#  'SUL': array([    24,     25,     26, ..., 103376, 103388, 103389], dtype=int64)}

# %%
#Retorna um dataframe apenas com as observações do grupo 'NORDESTE'
NOR = grupos.get_group('NORDESTE')
NOR.head()
# Out:
#   DATA INICIAL  DATA FINAL    REGIÃO    ESTADO           PRODUTO  \
# 4   2004-05-09  2004-05-15  NORDESTE   ALAGOAS  ETANOL HIDRATADO
# 5   2004-05-09  2004-05-15  NORDESTE     BAHIA  ETANOL HIDRATADO
# 6   2004-05-09  2004-05-15  NORDESTE     CEARA  ETANOL HIDRATADO
# 7   2004-05-09  2004-05-15  NORDESTE  MARANHAO  ETANOL HIDRATADO
# 8   2004-05-09  2004-05-15  NORDESTE   PARAIBA  ETANOL HIDRATADO
#
#    NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# 4                           103              R$/l                1.181
# 5                           408              R$/l                1.383
# 6                           278              R$/l                1.453
# 7                           105              R$/l                1.631
# 8                           125              R$/l                1.284
#
#    DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  PREÇO MÁXIMO REVENDA  \
# 4                  0.078                 1.050                 1.400
# ...

# %%
NOR.describe()
# Out:
#        NÚMERO DE POSTOS PESQUISADOS  PREÇO MÉDIO REVENDA  \
# count                  35788.000000         35788.000000
# mean                     124.721834             9.558746
# std                      113.110808            15.988848
# min                        1.000000             0.975000
# 25%                       41.000000             1.981000
# 50%                       95.000000             2.624000
# 75%                      169.000000             3.580000
# max                      625.000000            79.630000
#
#        DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  PREÇO MÁXIMO REVENDA  \
# count           35788.000000          35788.000000          35788.000000
# mean                0.552230              8.375173             10.788018
# std                 1.233842             13.737137             18.432933
# min                 0.000000              0.790000              0.999000
# 25%                 0.062000              1.850000              2.200000
# ...

# %%
grupos.mean()
# Out:
# C:\Users\joaod\AppData\Local\Temp\ipykernel_81188\1316802999.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   grupos.mean()
#               NÚMERO DE POSTOS PESQUISADOS  PREÇO MÉDIO REVENDA  \
# REGIÃO
# CENTRO OESTE                    144.898453            12.299706
# NORDESTE                        124.721834             9.558746
# NORTE                            67.835958            12.633086
# SUDESTE                         726.068024             9.828218
# SUL                             366.266423            10.254388
#
#               DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  \
# REGIÃO
# CENTRO OESTE               0.695078             10.610077
# NORDESTE                   0.552230              8.375173
# NORTE                      0.718957             11.410176
# ...

# %% [markdown]
# * Verificando o preço médio de cada produto (Combustível) para cada região?

# %%
RER = data_final.groupby(['REGIÃO', 'PRODUTO'])
RER

# %%
RER.groups
# Out:
# {('CENTRO OESTE', 'ETANOL HIDRATADO'): [0, 1, 2, 3, 27, 28, 29, 30, 54, 55, 56, 57, 81, 82, 83, 84, 108, 109, 110, 111, 135, 136, 137, 138, 162, 163, 164, 165, 189, 190, 191, 192, 216, 217, 218, 219, 243, 244, 245, 246, 270, 271, 272, 273, 297, 298, 299, 300, 324, 325, 326, 327, 351, 352, 353, 354, 378, 379, 380, 381, 405, 406, 407, 408, 432, 433, 434, 435, 459, 460, 461, 462, 486, 487, 488, 489, 513, 514, 515, 516, 540, 541, 542, 543, 567, 568, 569, 570, 594, 595, 596, 597, 621, 622, 623, 624, 648, 649, 650, 651, ...], ('CENTRO OESTE', 'GASOLINA COMUM'): [11980, 11981, 11982, 11983, 12007, 12008, 12009, 12010, 12034, 12035, 12036, 12037, 12061, 12062, 12063, 12064, 12088, 12089, 12090, 12091, 12115, 12116, 12117, 12118, 12142, 12143, 12144, 12145, 12169, 12170, 12171, 12172, 12196, 12197, 12198, 12199, 12223, 12224, 12225, 12226, 12250, 12251, 12252, 12253, 12277, 12278, 12279, 12280, 12304, 12305, 12306, 12307, 12331, 12332, 12333, 12334, 12358, 12359, 12360, 12361, 12385, 12386, 1
# ...

# %%
RER.mean()
# Out:
# C:\Users\joaod\AppData\Local\Temp\ipykernel_81188\2816657846.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   RER.mean()
#                                NÚMERO DE POSTOS PESQUISADOS  \
# REGIÃO       PRODUTO
# CENTRO OESTE ETANOL HIDRATADO                    155.514414
#              GASOLINA COMUM                      155.447352
#              GLP                                 202.113944
#              GNV                                   3.759150
#              ÓLEO DIESEL                         131.940332
#              ÓLEO DIESEL S10                      76.054545
# NORDESTE     ETANOL HIDRATADO                    154.143770
#              GASOLINA COMUM                      174.051678
#              GLP                                 127.294072
# ...

# %% [markdown]
# * ```.agg```: agrega(roda) uma serie de funções para os elementos de um dataframe ou de grupos de um dataframe.

# %%
df = pd.DataFrame(
    [[1, 2, 3],
    [4, 5, 6],
    [7, 8, 9],
    [None, None, None]], columns = ['A', 'B', 'C'])

df
# Out:
#      A    B    C
# 0  1.0  2.0  3.0
# 1  4.0  5.0  6.0
# 2  7.0  8.0  9.0
# 3  NaN  NaN  NaN

# %%
df.agg(['sum', 'min'])
# Out:
#         A     B     C
# sum  12.0  15.0  18.0
# min   1.0   2.0   3.0

# %%
#Computa o menor e maior valor do 'PREÇO MÉDIO REVENDA' para cada região (grupo)
grupos['PREÇO MÉDIO REVENDA'].agg(['min', 'max'])
# Out:
#                 min     max
# REGIÃO
# CENTRO OESTE  1.097  99.357
# NORDESTE      0.975  79.630
# NORTE         1.226  87.270
# SUDESTE       0.766  79.192
# SUL           0.922  72.088

# %% [markdown]
# #### Ordenação

# %%
notas = pd.DataFrame({
    'nome': ['João', 'Maria', 'José', 'Alice'],
    'idade': [20, 21, 19, 20],
    'nota_final': [5.0, 10.0, 6.0, 10.0]
})
notas
# Out:
#     nome  idade  nota_final
# 0   João     20         5.0
# 1  Maria     21        10.0
# 2   José     19         6.0
# 3  Alice     20        10.0

# %% [markdown]
# * ```sort_values```:Ordena valores ao longo de um eixo.
#
# Por padrão, o método retorna uma cópia dos dados ordenados em ordem crescente (ascendente). Podemos alterar isso pelo argumento ```ascending```.

# %%
notas.sort_values(by='nota_final', ascending = False)
# Out:
#     nome  idade  nota_final
# 1  Maria     21        10.0
# 3  Alice     20        10.0
# 2   José     19         6.0
# 0   João     20         5.0

# %%
#Nós também pddemos ordenar a partir de mais de uma coluna.

notas.sort_values(by=['nota_final', 'nome'], ascending = [False, True]).reset_index(drop = True)
# Out:
#     nome  idade  nota_final
# 0  Alice     20        10.0
# 1  Maria     21        10.0
# 2   José     19         6.0
# 3   João     20         5.0
